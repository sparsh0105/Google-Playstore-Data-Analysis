# %% [markdown]
# # Data Visualisation & Analysis with Python
#
# Here I have used a dataset that contains information about different applications present on Google Playstore
#
# With the help of Chatgpt , I have generated some questions that can be important for the Zoom advertising agency so that they can focus on promoting advertisements on particular applications which are trending in the market and can lead to maximum profits
#
# Apart from this main question I have divided the questions in the following ways : one that require data visualizations for agency, other that are statistical based questions.

# %% [markdown]
# Questions requiring data visualizations for Advertising Agency:
#
# - What are the top 10 most installed applications?
# - How do application sizes vary across categories?
# - How do the average ratings compare across different categories?
# - What is the proportion of ad-supported applications in each category?
# - How do the number of installs compare between applications that are editor's choice and those that are not?
#
# Questions requiring statistical analysis:
#
# - What is the average rating of applications in different categories?
# - What is the correlation between application size and number of installations?
# - Do higher-rated applications tend to have more reviews?
# - Do more reviews mean more installs
# - What is the relationship between the price of an application and its rating?

# %% [markdown]
# ## Data Description:
# - App: Application Name
# - Category: Category the app belongs to (Others category contain apps from various different categories excluded from the dataset)
# - Rating: Overall user rating of the app
# - Reviews: Number of user reviews for the app
# - Size: Size of the app in kilobytes
# - Installs: Number of user downloads/installs for the app
# - Paid/Free: Whether an app is paid or free
# - Price: price of an app in dollars
# - Content Rating: Age group the app is targeted at
# - Ad Supported: whether an app supports an Ad or not (Yes/No)
# - In App Purchases: App containing in app purchase feature or not (Yes/No)
# - Editors Choice: Whether rated as Editor Choice (Yes/No)

# %% [markdown]
# **Importing libraries for data analysis**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Reading the datasets**

# %%
data = pd.read_csv('Play_Store_2.csv')

# %% [markdown]
# **Displaying the first few rows of the dataset**

# %%
data.head()
# Out:
#                      App             Category  Rating   Reviews   Size  \
# 0            War Dragons               Others     3.9  160604.0  270.0
# 1  CV-Library Job Search             BUSINESS     4.4       NaN   46.0
# 2        Surah Al-Waqiah  BOOKS_AND_REFERENCE     NaN    1201.0   29.0
# 3                     Ay               Others     NaN      11.0   36.0
# 4                EA Plus               Others     2.5      12.0   12.0
#
#      Installs Paid/Free  Price Content Rating Ad Supported In App Purchases  \
# 0  10000000.0      Free    0.0       Everyone          Yes              Yes
# 1    100000.0      Free    0.0       Everyone           No               No
# 2    100000.0      Free    0.0       Everyone          Yes               No
# 3      5000.0      Free    0.0           Teen          Yes               No
# 4      1000.0      Free    0.0       Everyone           No               No
#
#   Editors Choice
# 0            Yes
# 1             No
# 2             No
# 3             No
# 4             No

# %% [markdown]
# The dataset has been loaded properly
# - *Dataset consists of several columns displaying the various attributes related to each App*
# - *` Category` columns display the category of the App.*
# - *The performance of each App has been defined by the users under `Ratings` and `Reviews` columns*
# - *Column `Content Rating` displays the Age Group of the users for which the App has been developed*
# - *Dataset has also been categorised on the basis of Ads Present in the App under the `Ad Supported` column and whether some of the features in the App are paid or not under the `In App Purchases` column*
# - *` Editors Choice` displays whether the App has been Recommended by the Editor or not*
# - *From the head of the dataset, it can be observed that there are some values as NaN, which means the dataset contains some missing values*

# %% [markdown]
# **Checking the data types of the columns for the dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4153 entries, 0 to 4152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   App               4153 non-null   object
#  1   Category          4153 non-null   object
#  2   Rating            3976 non-null   float64
#  3   Reviews           4029 non-null   float64
#  4   Size              4153 non-null   float64
#  5   Installs          4153 non-null   float64
#  6   Paid/Free         4153 non-null   object
#  7   Price             4153 non-null   float64
#  8   Content Rating    4153 non-null   object
#  9   Ad Supported      4153 non-null   object
#  10  In App Purchases  4153 non-null   object
#  11  Editors Choice    4153 non-null   object
# dtypes: float64(5), object(7)
# memory usage: 389.5+ KB

# %% [markdown]
# **Checking the shape of Dataset**

# %%
data.shape
# Out:
# (4153, 12)

# %% [markdown]
# The Dataset has 4153 number of rows with 12 columns

# %% [markdown]
# - *We can observe that there around 7 object datatype columns and 5 numerical datatype*
# - *All the columns does not have 4153 observations, which can be inferred that there are null values present in the dataset*

# %% [markdown]
# **Getting the statistical summary for the dataset**

# %%
data.describe(include = 'all').T
# Out:
#                    count unique          top  freq            mean  \
# App                 4153   4153  War Dragons     1             NaN
# Category            4153     15       Others  1288             NaN
# Rating            3976.0    NaN          NaN   NaN        4.189487
# Reviews           4029.0    NaN          NaN   NaN    66964.206751
# Size              4153.0    NaN          NaN   NaN       82.254408
# Installs          4153.0    NaN          NaN   NaN  3232705.641946
# Paid/Free           4153      2         Free  3828             NaN
# Price             4153.0    NaN          NaN   NaN        0.565341
# Content Rating      4153      4     Everyone  3251             NaN
# Ad Supported        4153      2          Yes  2208             NaN
# In App Purchases    4153      2           No  2586             NaN
# Editors Choice      4153      2           No  3304             NaN
#
#                              std    min      25%       50%        75%  \
# App                          NaN    NaN      NaN       NaN        NaN
# Category                     NaN    NaN      NaN       NaN        NaN
# Rating                  0.519792    1.0      4.0       4.3        4.5
# Reviews             107418.85154    1.0    224.0    7461.0    78219.0
# Size                   92.256334  0.011     22.0      42.0       84.0
# Installs          5421343.284861    1.0  10000.0  500000.0  5000000.0
# Paid/Free                    NaN    NaN      NaN       NaN        NaN
# Price                   8.926313    0.0      0.0       0.0        0.0
# Content Rating               NaN    NaN      NaN       NaN        NaN
# Ad Supported                 NaN    NaN      NaN       NaN        NaN
# In App Purchases             NaN    NaN      NaN       NaN        NaN
# Editors Choice               NaN    NaN      NaN       NaN        NaN
#
#                          max
# App                      NaN
# Category                 NaN
# Rating                   5.0
# Reviews             312204.0
# Size                   270.0
# Installs          19970000.0
# Paid/Free                NaN
# Price                 399.99
# Content Rating           NaN
# Ad Supported             NaN
# In App Purchases         NaN
# Editors Choice           NaN

# %% [markdown]
# - *The above table displays the descriptive analysis for Numerical columns*
# - *It can be observed that the average rating of Apps is around 4.19, which means most of the Apps have received ratings above average. As it can be seen that 75% of users have given ratings equal to or greater than 4 to the Apps*
# - *50% of the apps have received reviews less than 10000, which means users are not preferring to give reviews for most of the apps. The average value is high because of the range of number of reviews as the maximum number of reviews given to an app is very high*
# - *Around 90% of the apps are free of cost in the Play store*
# - *There are around 16 categories of Apps present in the Dataset among which 31% of apps are categorised in the Others category*
# - *The distribution of apps containing Ads is almost equal in 50:50 ratio, which means in an overall view, there is no trend whether apps are ad-supported or not*
# - *Similarly there is an almost equal distribution of apps which contain in App Purchases or not*
# - *Around 80% of the apps are not recommended by the Editors*

# %% [markdown]
# ## Missing Value Treatment

# %%
# checking missing values
data.isnull().sum()
# Out:
# App                   0
# Category              0
# Rating              177
# Reviews             124
# Size                  0
# Installs              0
# Paid/Free             0
# Price                 0
# Content Rating        0
# Ad Supported          0
# In App Purchases      0
# Editors Choice        0
# dtype: int64

# %% [markdown]
# - *The variable `Rating` and `Reviews ` have 177 and 127 missing values in them*
# - *There are no missing values in other variables.*

# %% [markdown]
# We can impute the missing values for each column seperately

# %% [markdown]
# Since the average value of column Rating is close to median of that column, hence we can impute the missing values with the mean value of that column

# %%
data['Rating'] = data['Rating'].fillna(value = data['Rating'].mean())

# %%
data.isnull().sum()
# Out:
# App                   0
# Category              0
# Rating                0
# Reviews             124
# Size                  0
# Installs              0
# Paid/Free             0
# Price                 0
# Content Rating        0
# Ad Supported          0
# In App Purchases      0
# Editors Choice        0
# dtype: int64

# %% [markdown]
# For the Review column, we can impute the missing values with median as the range is too high to impute the values with the average value of reviews

# %%
sns.histplot(data = data , x = 'Reviews', kde = True);

# %%
data['Reviews'] = data['Reviews'].fillna(value = data['Reviews'].median())

# %%
data.isnull().sum()
# Out:
# App                 0
# Category            0
# Rating              0
# Reviews             0
# Size                0
# Installs            0
# Paid/Free           0
# Price               0
# Content Rating      0
# Ad Supported        0
# In App Purchases    0
# Editors Choice      0
# dtype: int64

# %% [markdown]
# *All the missing values have been imputed and there are no missing values in our dataset now.*

# %% [markdown]
# ## Duplicate Rows Treatment

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# *Here we can see that there are no duplicated values so thats a good sign*

# %% [markdown]
# ## Univariate Data Analysis

# %% [markdown]
# **Let us first explore the numerical variables.**

# %% [markdown]
# **Observations on Rating**

# %%
sns.histplot(data = data , x = 'Rating', kde = True);
plt.show()
sns.boxplot(data = data , x = 'Rating');

# %% [markdown]
# - *The distribution of Rating is highly left skewed*
# - *There are a lot of outliers in this variable*
# - *Most of the ratings are on the higher side*

# %% [markdown]
# **Observations on Reviews**

# %%
sns.histplot(data = data , x = 'Reviews', kde = True);
plt.show()
sns.boxplot(data = data , x = 'Reviews');

# %% [markdown]
# - *The distribution of Reviews is extremely right skewed*
# - *There are a lot of outliers in this variable*
# - *Most of the reviews are on the lower side*

# %% [markdown]
# **Observations on Size**

# %%
sns.histplot(data = data , x = 'Size',kde = True);
plt.show()
sns.boxplot(data = data , x = 'Size');

# %% [markdown]
# - *The distribution of Size is distributed between 0 - 100 kb, which means most of the apps size are in this range*
# - *There are some outliers present at the extreme end, which means some of the apps have download size in Megabytes*
# - *Most of the reviews are on the lower side*

# %% [markdown]
# **Observations on Installs**

# %%
sns.histplot(data = data , x = 'Installs',kde = True);
plt.show()
sns.boxplot(data = data , x = 'Installs');

# %% [markdown]
# - *The distribution of installs is randomly distributed as multiple modes can be seen in the plot*
# - *From the box plot, it can be observed that most of the apps are installed 25% of the apps which are installed maximum number of times*

# %% [markdown]
# **Observations on Price**

# %%
plt.ylim(0,5000)
sns.histplot(data = data , x = 'Price',kde = True);
plt.show()
sns.boxplot(data = data , x = 'Price');

# %% [markdown]
# - *As we have already seen in our descriptive analysis, most of the apps have zero price to use*
# - *From the box plot, it can be observed that there are some outliers present in the price column*

# %% [markdown]
# **Let's now explore the Categorical columns.**

# %% [markdown]
# **Observations on Category**

# %%
plt.xticks(rotation = 90)
sns.countplot(data = data , x = 'Category',palette = 'dark');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_17276\1673825150.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data , x = 'Category',palette = 'dark');

# %% [markdown]
# - *Apps present under Others category are maximum in number*
# - *Apart from Others category, most of the apps are in Family Category comprising around 17% of the total apps*
# - *Very few apps around 1-2% of apps are in Books and Reference, and Communication Category*

# %% [markdown]
# **Observations on Paid/Free**

# %%
plt.xticks(rotation = 90)
sns.countplot(data = data , x = 'Paid/Free', palette = 'deep');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_17276\3573591991.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data , x = 'Paid/Free', palette = 'deep');

# %% [markdown]
# - *Around 91% of the apps are free to use in play store*

# %% [markdown]
# **Observations on Content Rating**

# %%
sns.countplot(data = data , x = 'Content Rating',palette = 'pastel');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_17276\2979938588.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data , x = 'Content Rating',palette = 'pastel');

# %% [markdown]
# - *Most of the apps have a content rating of 'Everyone', which means around 75% of apps can be used by all age groups of users*

# %% [markdown]
# **Observations on Ad Supported**

# %%
sns.countplot(data = data , x = 'Ad Supported', palette = 'muted');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_17276\11290077.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data , x = 'Ad Supported', palette = 'muted');

# %% [markdown]
# - *Although there is not much significant difference between the apps which support the Ads and not, it can still be observed that Apps which support Ads are 6% higher than Apps which do not support Ads*

# %% [markdown]
# **Observations on In App Purchase**

# %%
sns.countplot(data = data , x = 'In App Purchases', palette = 'bright');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_17276\509065296.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data , x = 'In App Purchases', palette = 'bright');

# %% [markdown]
# - *It is interesting to note that most of the apps do no have feature of In app purchases*
# - *Only 36% of the apps have In app purchases feature*

# %% [markdown]
# **Observations on In Editors Choice**

# %%
sns.countplot(data = data , x = 'Editors Choice', palette = 'colorblind');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_17276\2627694996.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data , x = 'Editors Choice', palette = 'colorblind');

# %% [markdown]
# - *Around 80% of the apps are not recommended by the Editors*

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# Let's check relationship of categories with ratings and reviews as to know which category is trending

# %%
plt.figure(figsize = (20,8))
plt.xticks(rotation = 90)
sns.boxplot(data = data , x = 'Category' , y = 'Rating', palette = 'pastel');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_17276\1583413077.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = data , x = 'Category' , y = 'Rating', palette = 'pastel');

# %% [markdown]
# - *As it can be observed that median ratings of all categories are above 4 with some outliers at the bottom, which means 50% of the apps in Play Store
#   have been rated more than 4*

# %%
plt.figure(figsize = (15,8))
plt.xticks(rotation = 90)
sns.lineplot(data = data , x = 'Category', y = 'Reviews', ci = False, estimator = 'sum');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_2124\1028766747.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = data , x = 'Category', y = 'Reviews', ci = False, estimator = 'sum');

# %% [markdown]
# - *Others category has recieved highest number of reviews*
# - *Apart from that, Category **Game** has received highest reviews from the users followed by **Family** Category*
# - *It should be noted that even though category **Family** has apps more than category **Game**, but it has received less number of reviews than Game category*
# - *Therefore, it can be inferred that this category is less used by the users apart from the fact that it has high number of apps*

# %%
plt.figure(figsize= (15,8))
plt.xticks(rotation = 90)
sns.lineplot(data = data , x = 'Category' , y = 'Installs' , ci = False,estimator = 'sum');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_17276\3130605704.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = data , x = 'Category' , y = 'Installs' , ci = False,estimator = 'sum');

# %% [markdown]
# - *The trend of installation of apps is almost same as for the Reviews in apps*
# - *Apps present in category Game has been installed more number of times than any other Category except those apps which are under Others Category*
# - *Apps in Medical Category are installed least followed by Finance, Business and Books and References*

# %%
plt.figure(figsize= (15,8))
plt.xticks(rotation = 90)
sns.lineplot(data = data , x = 'Category' , y = 'Price' , ci = False,estimator = 'sum');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_2124\2204813054.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = data , x = 'Category' , y = 'Price' , ci = False,estimator = 'sum');

# %% [markdown]
# - *Apps present in Family Category are costliest as compared to any other Category*
# - *Even though the apps under Family category are costlier, the installation of these apps is higher than other apps except for Others and Game Category*
# - *It is interesting to observe that Apps under Finance and Medical categroy are also costlier, and this can be the reason that these apps are installed in a very less frequency*
# - *Business and Books and References apps are not costlier and they are not been installed by the users, which means the apps present in these categories are least preferred by the users*

# %%
plt.figure(figsize = (15,8))
plt.xticks(rotation = 90)
sns.countplot(data = data[data['Paid/Free'] == 'Free'] , x = 'Category' , hue = 'Ad Supported');

# %% [markdown]
# - *Among free apps, Others category is highest*
# - *Apart from that Family Category has higher number of apps followed by Game and Tools category*
# - *Family and Game category has apps which have a significant difference between apps supporting Ads or not*
# - *Apps under Medical and Finance like categories, higher proportion is towards apps which do not support Ads, even after they are free to use*

# %%
plt.figure(figsize = (15,8))
plt.xticks(rotation = 90)
sns.countplot(data = data[data['Ad Supported'] == 'Yes'], x = 'Category' , hue = 'Paid/Free');

# %% [markdown]
# - *Apps which have Ad support feature are mostly free to use in all the categories*

# %% [markdown]
# It is observed that Reviews and Installation followed almost similar trends, therefore they may have some relationship with each other.
#
# Let's check if there is any relationship between these 2 variables and also with any other variable

# %%
sns.scatterplot(data = data , x = 'Reviews' , y = 'Installs');

# %% [markdown]
# ## Reccomendations

# %% [markdown]
# 1. *Agency should focus on apps under **Family** category for Advertisement as they are significantly trending in the market. They can invest in other categories like **Game** and **Tools** as they also contain trending apps*
# 2. *Since apps which support Ads are mostly free to use, Agency should look forward to invest in free apps rather than paid apps*
# 3. *Investing in free apps under category like **Finance**, **Medical**, should be avoided as they do not support advertisements*
# 4. *As there is a high correlation between Reviews and Installations, therefore agency should check for those apps which have high number of reviews as those apps are more likely to get installed*
# 5. *Agency should not invest in apps under category **Business**, **Books and References** as they are not preferred by the users as they have very low number of installations even they are free to use*

# %% [markdown]
# Questions requiring data visualizations for Advertising Agency:
#
# - What are the top 10 most installed applications?
# - How do application sizes vary across categories?
# - How do the average ratings compare across different categories?
# - What is the proportion of ad-supported applications in each category?
# - How do the number of installs compare between applications that are editor's choice and those that are not?

# %%
# What are the top 10 most installed applications?
plt.title('Top 10 Most Installed Applications')
top10 = data.sort_values('Installs',ascending = False).head(10)
plt.xticks(rotation = 90)
sns.countplot(data = top10 , x = 'App', palette = 'pastel');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_860\1449239613.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = top10 , x = 'App', palette = 'pastel');

# %% [markdown]
# We can see from the above graph that these are the top 10 most installed apps

# %%
# How do application sizes vary across categories?
plt.figure(figsize = (10,5))
plt.xticks(rotation = 90)
plt.ylabel('Avg size in kb')
sns.boxplot(data = data , x = 'Category', y ='Size', palette = 'deep');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_860\2174051507.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = data , x = 'Category', y ='Size', palette = 'deep');

# %% [markdown]
# We can see that application under Others category are biggest in size followed by applications under Health and Fitness

# %%
# How do the average ratings compare across different categories?
plt.figure(figsize = (10,5))
plt.xticks(rotation = 90)
plt.ylabel('Average Rating')
sns.barplot(data = data , x = 'Category' , y = 'Rating' , palette = 'muted');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_860\3926798566.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = data , x = 'Category' , y = 'Rating' , palette = 'muted');

# %% [markdown]
# We can see that average rating for each category is above 4.0

# %%
# What is the proportion of ad-supported applications in each category?
plt.figure(figsize = (15,5))
plt.xticks(rotation = 90)
sns.countplot(data = data , x = 'Category' , hue = 'Ad Supported');

# %% [markdown]
# We can observe that Others category is the most ad supporting category followed by Family and Game

# %%
# How do the number of installs compare between applications that are editor's choice and those that are not?
sns.barplot(data = data , y = 'Installs', x = 'Editors Choice', palette = 'pastel');
# Out:
# C:\Users\Sparsh Gupta\AppData\Local\Temp\ipykernel_860\1703760236.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = data , y = 'Installs', x = 'Editors Choice', palette = 'pastel');

# %% [markdown]
# From the visualization, it's clear that Editor's Choice apps tend to have a higher average number of installs compared to those that are not Editor's Choice.

# %% [markdown]
# Questions requiring statistical analysis:
#
# - What is the average rating of applications in different categories?
# - What is the correlation between application size and number of installations?
# - Do higher-rated applications tend to have more reviews?
# - Do more reviews mean more installs
# - What is the relationship between the price of an application and its rating?

# %%
# What is the average rating of applications in different categories?
data.groupby('Category')['Rating'].mean()
# Out:
# Category
# BOOKS_AND_REFERENCE    4.367901
# BUSINESS               4.173214
# COMMUNICATION          4.004348
# FAMILY                 4.194610
# FINANCE                4.111034
# GAME                   4.288864
# HEALTH_AND_FITNESS     4.270588
# LIFESTYLE              4.114925
# MEDICAL                4.148936
# Others                 4.215592
# PERSONALIZATION        4.297368
# PHOTOGRAPHY            4.074561
# PRODUCTIVITY           4.133898
# SPORTS                 4.228682
# TOOLS                  3.994483
# Name: Rating, dtype: float64

# %%
# What is the correlation between application size and number of installations?
data[['Size','Installs']].corr()
# Out:
#               Size  Installs
# Size      1.000000  0.332146
# Installs  0.332146  1.000000

# %%
# Do higher-rated applications tend to have more reviews?
data[['Rating','Reviews']].corr()
# Out:
#            Rating   Reviews
# Rating   1.000000  0.192627
# Reviews  0.192627  1.000000

# %%
# Do more reviews mean more installs
data[['Reviews','Installs']].corr()
# Out:
#            Reviews  Installs
# Reviews   1.000000  0.863924
# Installs  0.863924  1.000000

# %% [markdown]
# Yes it is seen that the app with more reviews is installed more

# %%
# What is the relationship between the price of an application and its rating?
data[['Price','Rating']].corr()
# Out:
#            Price    Rating
# Price   1.000000 -0.003814
# Rating -0.003814  1.000000

# %% [markdown]
# We can see that price and rating are negatively correlated which means as the price of the application incrase its rating decrease
